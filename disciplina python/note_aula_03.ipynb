# %%
tupla_fofa = ("cachorro", "hamster")
tupla_fofa
# Out:
# ('cachorro', 'hamster')

# %%
lista_linda=[10,20,30,55,100]
lista_linda
# Out:
# [10, 20, 30, 55, 100]

# %%
dicio={"nome":"Maria", "sobrenome":"Silva", "idade":30}
dicio
dicio['nome']
dicio.items()
30 in dicio.values()
# Out:
# True

# %%
dicio_int={1:'ab', 2:'rr', 3:00}
dicio_int[2]
# Out:
# 'rr'

# %%
set_top={1,3,4,4,6,7,0}
set_top
# Out:
# {0, 1, 3, 4, 6, 7}

# %%
print(type(lista_linda))
print(type(lista_linda[1]))
print(lista_linda)
# Out:
# <class 'list'>
# <class 'int'>
# [10, 20, 30, 55, 100]

# %%
#para ver os elementos contando do final pro começo, quando nao sei quantos elementos tem.
print(lista_linda)
lista_linda[-1]
# Out:
# [10, 20, 30, 55, 100]
# 100

# %%
#adicionar elemento na ultima posição do objeto composto
lista_linda.append(200)
lista_linda
# Out:
# [10, 20, 30, 55, 100, 200, 200]

# %%
#adicionar elemento em dicionario
dicio['chave nova']='valor novo'
dicio
# Out:
# {'nome': 'Maria',
#  'sobrenome': 'Silva',
#  'idade': 30,
#  'chave nova': 'valor novo'}

# %%
#forma de formatar o print
print(f"{lista_linda}") 
print(f"{dicio}")
# Out:
# [10, 20, 30, 55, 100, 200]
# {'nome': 'Maria', 'sobrenome': 'Silva', 'idade': 30}

# %%
#buscar o ultimo elemento da lista e apagar ele da lista
#cada vez que rodar esse comando, o ultimo elemento da lista vai ser apagado, sucessivamente.
lista_linda.pop()
# Out:
# 200

# %%
num = lista_linda.pop()
num = num + 1
lista_linda.append(num)
lista_linda
# Out:
# [10, 20, 30, 55, 100, 202]

# %%
#multi indexação com obj novo
novo_obj=lista_linda[2]
novo_obj
# Out:
# 30

# %%
#seguindo a ordem, a recebeu o primeiro elemento da lista, b recebeu o que sobrou no meio e c recebeu o ultimo.
a, *b, c = lista_linda
print(a,b,c)
# Out:
# 10 [20, 30, 55, 100] 202

# %% [markdown]
# # Exercício 01:

# %% [markdown]
# No paradigma de Programação Orientada a Objetos, o que é um Objeto?
# R.: Objeto é toda instância de uma classe, que possui atributos e métodos.

# %% [markdown]
# # Exercício 02:

# %% [markdown]
# Em Python, o método com nome count() faz parte do objeto da classe string. Este objeto possuí outros atributos e métodos. Qual o código que pode ser usado para verificar se count() é um método também presente no objeto da classe integer?

# %%
#dir vai listar todos os atributos e métodos disponíveis para um objeto. Por exemplo, para a classe inteiro, o que nao inclui count():
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %% [markdown]
# # Exercício 03:

# %% [markdown]
# Marque V para nomes de variáveis válidos e F para nomes inválidos em Python?

# %% [markdown]
# (v) nome_objeto
# <br>(f) 1_nome _objeto
# <br>(f) #nome_objeto
# <br>(v) nome1_objeto
# <br>(f) lambda
# <br>(v) nome_lambda

# %% [markdown]
# (v) lambda_nome
# <br>(f) @_nome_objeto
# <br>(f) Nome objeto
# <br>(v) NOME_OBJETO
# <br>(v) nome_Objeto
# <br>(v) nomeLambda

# %% [markdown]
# # Exercício 04:

# %% [markdown]
# Para instanciar uma variável que recebe um valor inteiro, com o nome objeto_inteiro, como deve ser o código em Python?

# %%
objeto_inteiro=10

# %% [markdown]
# # Exercício 05:

# %% [markdown]
# Para instanciar uma variável que recebe um valor decimal, com o nome objeto_decimal, como deve ser o código em Python?

# %%
objeto_decimal=10.5

# %% [markdown]
# # Exercício 06:

# %% [markdown]
# Escreva a classe de objeto ideal para se representar cada uma das seguintes informações:

# %% [markdown]
# (a) O número da casa em um endereço
# <br>R.: inteiro
# <br>
# <br>
# (b) A data de nascimento de uma pessoa
# <br>R.: string
# <br>
# <br>
# (c) Se uma pessoa é diabética ou não
# <br>R.: booleano
# <br>
# <br>
# (d) A altura de uma pessoa em metros
# <br>R.: flutuante
# <br>
# <br>
# (e) O resultado da divisão de 5 por 2
# <br>R.: flutuante
# <br>
# <br>
# (f) O resultado da multiplicação de 2,5 por 2
# <br>R.: inteiro
# <br>
# <br>

# %% [markdown]
# # Exercício 07:

# %% [markdown]
# Identifique a classe de objeto em Python dos seguintes valores:

# %% [markdown]
# (a) "9 de agosto de 1968"
# <br>R.: string
# <br>
# <br>
# (b) 1.3
# <br>R.: flutuante
# <br>
# <br>
# (c) False
# <br>R.: booleano
# <br>
# <br>
# (d) -31
# <br>R.: inteiro
# <br>
# <br>
# (e) “?”
# <br>R.: string
# <br>
# <br>
# (f) ‘1979’
# <br>R.: string
# <br>
# <br>

# %% [markdown]
# # Exercício 08:

# %% [markdown]
# Instancie variáveis das classes abaixo, recebendo qualquer valor, e retorne os resultados:
#
# - string
# - float
# - booleano
# - inteiro

# %%
obj_str="sou string" 
obj_str

# %%
obj_float=100000.1 
obj_float

# %%
obj_bool=True 
obj_bool

# %%
obj_int=5 
obj_int

# %% [markdown]
# # Exercício 09:

# %% [markdown]
# Escreva a classe de objeto ideal para se representar cada uma das seguintes informações:

# %% [markdown]
# ( ) O nome de um gene;
# <br>R.: String
# <br>
# <br>
# ( ) O fold change (razão) de expressão de uma proteína em relação ao controle;
# <br>R.: Flutuante
# <br>
# <br>
# ( ) Uma sequencia aminoacídica;
# <br>R.: String
# <br>
# <br>
# ( ) Classificar um gene como up ou down regulated;
# <br>R.: Booleano
# <br>
# <br>
# ( ) O número de genes classificados como up ou down regulated
# <br>R.: Inteiro
# <br>
# <br>

# %% [markdown]
# # Exercício 10:

# %% [markdown]
# Dado a variável abaixo, qual método pode ser utilizado para buscar o número de ocorrências da sequencia “AUG” presentes no objeto?
